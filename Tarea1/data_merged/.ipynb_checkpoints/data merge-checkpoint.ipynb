# %%
import pandas as pd

#Lectura de modelos de datos.
df_alumnos = pd.read_csv("../data_sources/alumnos_ds.csv", sep=";")
df_asignaturas = pd.read_csv("../data_sources/asignaturas_ds.csv", sep =";")
df_carreras = pd.read_csv("../data_sources/carreras_ds.csv", sep =";")
df_catedraticos = pd.read_csv("../data_sources/catedraticos_ds.csv", sep =";")
df_departamentos = pd.read_csv("../data_sources/departamentos_ds.csv", sep =";")
df_tiempo = pd.read_csv("../data_sources/tiempo_ds.csv", sep =";")
df_rendimiento = pd.read_json("../data_sources/rendimiento.json", orient='split')

#df_rendimiento
#df_alumnos

# %%
#merge a la data relacionada con asignaturas (segun modelo)
df_new_subjects = pd.merge(df_asignaturas, df_departamentos, on = 'id_departamento')
#df_new_subjects

# %%
#merge a la data relacionada con alumnos (segun modelo)
df_new_students = pd.merge(df_alumnos, df_carreras, on = 'id_carrera')
#df_new_students

# %%
#merge data para hacer un solo dataframe
df_new_data = df_rendimiento.merge(df_tiempo, on = 'fecha_registro').merge(df_catedraticos, on = 'dni_catedratico').merge(df_new_subjects, on = 'id_asignatura').merge(df_new_students, on = 'dni_alumno')
#df_new_data
# Out:
#          dni_alumno id_asignatura  dni_catedratico fecha_registro  promedio  \
# 0   1679-2001-57399        PP-003  3132-1987-54944     12/14/2020      94.5
# 1   1679-2001-57399        PP-003  3132-1987-54944     12/14/2020      94.5
# 2   1679-2001-57399        MM-110  8177-1971-05435       5/4/2020      80.0
# 3   9780-1995-53373        PP-003  3132-1987-54944     12/14/2020      90.0
# 4   9780-1995-53373        PP-003  3132-1987-54944     12/14/2020      90.0
# 5   3963-2002-29205        PP-003  3185-1969-68586     12/13/2020      95.0
# 6   3963-2002-29205        PP-003  3185-1969-68586       5/5/2020      60.0
# 7   1622-2003-76390        PP-003  8177-1971-05435       5/5/2021      54.0
# 8   4513-2005-15937        MM-110  3132-1987-54944     12/14/2020      92.5
# 9   4513-2005-15937        MM-110  3132-1987-54944     12/14/2020      92.5
# 10  7953-2002-40541        MM-110  3132-1987-54944       5/6/2020      60.5
# 11  6877-1999-84575        MM-110  3132-1987-54944       5/4/2020      64.2
# 12  0372-2004-69530        MM-110  3185-1969-68586     12/14/2020      61.2
# 13  0372-2004-69530        MM-110  3185-1969-68586     12/14/2020      61.2
# 14  7219-1992-14916        MM-110  8177-1971-05435       5/5/2021      94.0
# 15  8675-2005-35773        DP-120  1049-1969-32925     12/14/2020      95.1
# 16  8675-2005-35773        DP-120  1049-1969-32925     12/14/2020      95.1
# 17  9040-1996-91077        DP-120  1049-1969-32925       5/5/2021      95.0
#
#     periodo  anio nombre_catedratico fecha_nacimiento_x genero_x  \
# 0         3  2020      Arnold Muffen           7/2/1987     Male
# 1         3  2020      Arnold Muffen           7/2/1987     Male
# 2         1  2020        Tan Dowling          1/21/1971     Male
# 3         3  2020      Arnold Muffen           7/2/1987     Male
# 4         3  2020      Arnold Muffen           7/2/1987     Male
# 5         3  2020  Alicea Van Giffen          1/12/1969   Female
# 6         1  2020  Alicea Van Giffen          1/12/1969   Female
# 7         1  2021        Tan Dowling          1/21/1971     Male
# 8         3  2020      Arnold Muffen           7/2/1987     Male
# 9         3  2020      Arnold Muffen           7/2/1987     Male
# 10        1  2020      Arnold Muffen           7/2/1987     Male
# 11        1  2020      Arnold Muffen           7/2/1987     Male
# 12        3  2020  Alicea Van Giffen          1/12/1969   Female
# 13        3  2020  Alicea Van Giffen          1/12/1969   Female
# 14        1  2021        Tan Dowling          1/21/1971     Male
# 15        3  2020       Bentley Izon          12/4/1969     Male
# 16        3  2020       Bentley Izon          12/4/1969     Male
# 17        1  2021       Bentley Izon          12/4/1969     Male
#
#    nombre_asignatura id_departamento nombre_departamento      nombre_alumno  \
# 0     Programacion I              MM          Matematica     Margie Nyssens
# 1     Programacion I              MM          Matematica     Margie Nyssens
# 2       Matematica I              MM          Matematica     Margie Nyssens
# 3     Programacion I              MM          Matematica    Analiese Sackey
# 4     Programacion I              MM          Matematica    Analiese Sackey
# 5     Programacion I              MM          Matematica    Ram Sommerville
# 6     Programacion I              MM          Matematica    Ram Sommerville
# 7     Programacion I              MM          Matematica      Ganny Caveill
# 8       Matematica I              MM          Matematica    Claudius Keyhoe
# 9       Matematica I              MM          Matematica    Claudius Keyhoe
# 10      Matematica I              MM          Matematica  Caitrin Galbraith
# 11      Matematica I              MM          Matematica     Delano Bulward
# 12      Matematica I              MM          Matematica   Ellsworth Nibley
# 13      Matematica I              MM          Matematica   Ellsworth Nibley
# 14      Matematica I              MM          Matematica       Brenn Fulham
# 15     Derecho Penal              DD             Derecho     Bailey Rearden
# 16     Derecho Penal              DD             Derecho     Bailey Rearden
# 17     Derecho Penal              DD             Derecho   Courtnay Rawdall
#
#    fecha_nacimiento_y genero_y id_carrera              nombre_carrera
# 0           5/16/2001   Female     ING-IE        Ingenieria Electrica
# 1           5/16/2001   Female     ING-IE        Ingenieria Electrica
# 2           5/16/2001   Female     ING-IE        Ingenieria Electrica
# 3          10/29/1995   Female     ING-IE        Ingenieria Electrica
# 4          10/29/1995   Female     ING-IE        Ingenieria Electrica
# 5           8/15/2002     Male     ING-IE        Ingenieria Electrica
# 6           8/15/2002     Male     ING-IE        Ingenieria Electrica
# 7            2/5/2003     Male     LIC-MM  Licenciatura en Matematica
# 8          12/31/2005     Male     ING-IE        Ingenieria Electrica
# 9          12/31/2005     Male     ING-IE        Ingenieria Electrica
# 10          12/7/2002   Female     ING-IE        Ingenieria Electrica
# 11          8/29/1999     Male     ING-IE        Ingenieria Electrica
# 12          1/26/2004     Male     ING-IE        Ingenieria Electrica
# 13          1/26/2004     Male     ING-IE        Ingenieria Electrica
# 14          5/29/1992   Female     LIC-MM  Licenciatura en Matematica
# 15          3/29/2005     Male      DD-PP                     Derecho
# 16          3/29/2005     Male      DD-PP                     Derecho
# 17         11/30/1996   Female      DD-PP                     Derecho

# %%
#Guardar el nuevo dataframe en un csv
df_new_data.to_csv('../data_sources/data_unida.csv', index = False, sep =";")
